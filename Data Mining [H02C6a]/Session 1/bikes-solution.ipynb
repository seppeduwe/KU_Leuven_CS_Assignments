# %% [markdown]
# # Bike rental usage
#
# In this exercise, we explore the dataset using visualisation techniques similar to that from Exercise 1.

# %%
import pandas as pd

br = pd.read_csv('bikes_train.csv', parse_dates=['datetime'])
print(br.shape)
br.head()
# Out:
# (10886, 12)
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  0.24  0.2879
# 1 2011-01-01 01:00:00       1        0           0        1  0.22  0.2727
# 2 2011-01-01 02:00:00       1        0           0        1  0.22  0.2727
# 3 2011-01-01 03:00:00       1        0           0        1  0.24  0.2879
# 4 2011-01-01 04:00:00       1        0           0        1  0.24  0.2879
#
#    humidity  windspeed  casual  registered  count
# 0      0.81          0       3          13     16
# 1      0.80          0       8          32     40
# 2      0.80          0       5          27     32
# 3      0.75          0       3          10     13
# 4      0.75          0       0           1      1

# %% [markdown]
# Attributes are as follows:
# - **Datetime**: date and time, hourly
# - **Season**: 1 = spring, 2 = summer, 3 = fall, 4 = winter
# - **Holiday**: whether the day is considered a holiday
# - **Workingday**: whether the day is neither a weekend nor holiday
# - **Weather**:
#     1. Clear, Few clouds, Partly cloudy, Partly cloudy
#     2. Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#     3. Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#     4. Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - **Temp**: temperature, Celsius
# - **Atemp**: "feels like" temperature, Celsius
# - **Humidity**: relative humidity
# - **Windspeed**: wind speed
# - **Casual**: number of non-registered user rentals initiated
# - **Registered**: number of registered user rentals initiated
# - **Count**: number of total rentals, *target variable*

# %% [markdown]
# ## Data aggregation

# %%
# Import the required models
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %% [markdown]
# `pandas` provides [functionality for convenient access to time series data](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#datetimeindex-partial-string-indexing). In order to make use of it, a data frame must be indexed on a time-like column.

# %%
# Facilitating time-based plotting
br_time_idx = br.set_index('datetime')

# %%
br_time_idx['count'].plot()

# %% [markdown]
# Now, make a similar plot aggragating bike usage by day.

# %%
br.groupby(br['datetime'].dt.date).agg({'count': 'sum'}).plot()

# %% [markdown]
# ## Data exploration
# Apply visualisation techniques similar to that from Exercise 1 to explore the dataset and find interesting patterns in bike rental usage.
